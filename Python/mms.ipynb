# %%
import sympy as sp
sp.init_printing()

# %%
r=sp.Symbol('r')
r1=sp.Symbol('r1')
r2=sp.Symbol('r2')
r3=sp.Symbol('r3')
k1=sp.Symbol('k1')
k2=sp.Symbol('k2')
k3=sp.Symbol('k3')
T1=sp.Symbol('T1')
T2=sp.Symbol('T2')
T3=sp.Symbol('T3')
T=sp.Symbol('T')
T2p=sp.Symbol('T2p')
T3p=sp.Symbol('T3p')
q1=sp.Symbol('q1')
q2=sp.Symbol('q2')
q3=sp.Symbol('q3')
#/(w**2)')
#T

T1=(r1**2)*sp.log(r2/r1)*(q1-q2)/(2*k2)+q2*(r2**2)/(4*k2)*(1-(r1**2)/(r2**2))+T2
T3p=(T3+q3*(r3**2)/(4*k3)*(1-(r**2)/(r3**2)) -(q3*(r3**2)/(4*k3)*(1-(r2**2)/(r3**2))+T3-T2)*(sp.log(r3/r)/sp.log(r3/r2)))*k3
T2p=(T2+q2*(r2**2)/(4*k2)*(1-(r**2)/(r2**2)) -(q2*(r2**2)/(4*k2)*(1-(r1**2)/(r2**2))+T2-T1)*(sp.log(r2/r)/sp.log(r2/r1)))*k2

dt3r=sp.diff(T3p,r).subs(r,r2).doit()
dt2r=sp.diff(T2p,r).subs(r,r2).doit()
#display(dt3r)
#display(dt2r)
#display(T1)

expr = dt3r-dt2r
display(expr) 
term=sp.solve(expr,T2)
term
#expr2 = dt3r-dt2r+T2*k3/(r2*sp.log(r3/r2))
#display(expr2) 
#sp.simplify(dt3r-dt2r+T2*k3/(r2*sp.log(r3/r2))) 
#a=dtr.subs(r,r2).doit()
#display(a)

#/(w**2)

#dtz=sp.Derivative(T,z)
#dtzs=sp.diff(T,z)
#dtr=sp.Derivative(T,r)
#dtrs=sp.diff(T,r)
#teste=(1/r)*sp.diff(k*r*sp.diff(T,r),r)+sp.diff(k*sp.diff(T,z),z)+Cb*w*(Ta)


#teste
#dtrs
# Out:
#                                     ⎛                  ⎛    2    ⎞        ⎞
#                                     ⎜                2 ⎜  r₂     ⎟        ⎟
#                                     ⎜           q₃⋅r₃ ⋅⎜- ─── + 1⎟        ⎟
#                                     ⎜                  ⎜    2    ⎟        ⎟
#                                     ⎜                  ⎝  r₃     ⎠        ⎟
#      ⎛            2          ⎞      ⎜-T₂ + T₃ + ──────────────────        ⎟
#      ⎜  q₂⋅r₂   r₁ ⋅(q₁ - q₂)⎟      ⎜                  4⋅k₃          q₃⋅r₂⎟
# - k₂⋅⎜- ───── - ─────────────⎟ + k₃⋅⎜───────────────────────────── - ─────⎟
#      ⎝   2⋅k₂      2⋅k₂⋅r₂   ⎠      ⎜                ⎛r₃⎞             2⋅k₃⎟
#                                     ⎜          r₂⋅log⎜──⎟                 ⎟
#                                     ⎝                ⎝r₂⎠                 ⎠
# ⎡                 2    ⎛r₃⎞          2    ⎛r₃⎞          2    ⎛r₃⎞          2
# ...

# %%
r=sp.Symbol('r')
z=sp.Symbol('z')
k=sp.Symbol('k')
w=sp.Symbol('w')
Q=sp.Symbol('Q')
T=sp.Symbol('T')
A=sp.Symbol('A')
B=sp.Symbol('B')
C1=sp.Symbol('C1')
C2=sp.Symbol('C2')
C3=sp.Symbol('C3')
C4=sp.Symbol('C4')
D=sp.Symbol('D')
E=sp.Symbol('E')
const=sp.Symbol('const')
#/(w**2)')
#T
Lr=sp.Symbol('Lr')
Lz=sp.Symbol('Lz')
Cb=sp.Symbol('Cb')
Rho=sp.Symbol('Rho')
Ta=sp.Symbol('Ta')
h=sp.Symbol('h')
T_inf=sp.Symbol('T_inf')



#k=-0.7*r/Lr+0.9*z/Lz
#display(k)
#w=5*(10**-4)*z/Lz-5*(10**-4)*r/Lr
#display(w)1

#T=r**2+const
T=P+C1*(e**(C2*r+C3)-1)*sp.sin(C4*z+C5)
#display(T)
#/(w**2)

dtz=sp.Derivative(T,z)
dtzs=sp.diff(T,z)
dtr=sp.Derivative(T,r)
dtrs=sp.diff(T,r)
teste=(1/r)*sp.diff(k*r*sp.diff(T,r),r)+sp.diff(k*sp.diff(T,z),z)+Cb*w*(Ta-0)



teste

#dtrs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-669b14ecdbe3> in <module>
#      32
#      33 #T=r**2+const
# ---> 34 T=P+C1*(e**(C2*r+C3)-1)*sp.sin(C4*z+C5)
#      35 #display(T)
#      36 #/(w**2)
#
# NameError: name 'e' is not defined

# %%
r=sp.Symbol('r')
z=sp.Symbol('z')
k=sp.Symbol('k')
kp=sp.Symbol('kp')
kls=sp.Symbol('kls')
wps=sp.Symbol('wps')
Q=sp.Symbol('Q')
T=sp.Symbol('T')
A=sp.Symbol('A')
B=sp.Symbol('B')
C1=sp.Symbol('C1', nonzero=True)
C2=sp.Symbol('C2', nonzero=True)
C3=sp.Symbol('C3', nonzero=True)
C4=sp.Symbol('C4', nonzero=True)
C5=sp.Symbol('C5')
B=sp.Symbol('B')
E=sp.Symbol('E')
const=sp.Symbol('const')
Lr=sp.Symbol('Lr')
Lz=sp.Symbol('Lz')
Cb=sp.Symbol('Cb')
Rhop=sp.Symbol('Rhop')
RN=sp.Symbol('RN')
RS=sp.Symbol('RS')
ZE=sp.Symbol('ZE')
ZW=sp.Symbol('ZW')
Ta=sp.Symbol('Ta')
h=sp.Symbol('h')
T_inf=sp.Symbol('T_inf')
P=sp.Symbol('P')
P2=sp.Symbol('P2')


#T_inf=0
P=T_inf
#P2=-(Lr**2)-kp*2*Lr/h#(-Lr-k*2*Lr/h)*sp.sin(C3*z+C4)
#P2=-sp.sin(C1*Lr+C2)-kp*C1*sp.cos(C1*Lr+C2)/h
P2=-sp.sin(C3*z+C4)
#B=-(Lr**2)-2*kp*Lr/h
#C1=1
#C2=(h*(sp.E**Lr)/k-h*Lr/k-(sp.E**Lr)+1)/((Lr**2)*h/k-2*Lr)

#C3=4*sp.pi/(Lz)
#C4=sp.pi/(2)


#T=P+(sp.E**(r)-C2*r**2-r)*sp.sin(C3*z+C4)
T=P+P2+sp.sin(C1*r+C2)*sp.sin(C3*z+C4) #B+(0)#*sp.sin(C3*z+C4)
#T=P+B+r**2
#display(T)
#/(w**2)

dtz=sp.Derivative(T,z)
dtzs=sp.diff(T,z)
dtr=sp.Derivative(T,r)
dtrs=sp.diff(T,r)
Q=(1/r)*sp.diff(kls*r*sp.diff(T,r),r)+sp.diff(kls*sp.diff(T,z),z)+Cb*Rhop*wps*(Ta-T)
display(Q)
#display(sp.fcode(Q))
Int1=sp.integrate(Q*r,(r,RS,RN))
#Int1=sp.integrate(Q*r,(r))
#display(Int1)
#display(sp.fcode(Int1))
Int2=-sp.integrate(Int1,(z))
display(Int2)
display(sp.fcode(Int2))
# Out:
#
#
# Cb⋅Rhop⋅wps⋅(-T_inf + Ta - sin(C₁⋅r + C₂)⋅sin(C₃⋅z + C₄) + sin(C₃⋅z + C₄)) + k
#
#
#                                                                     2
#    ⎛    2                                   2               ⎞   - C₁ ⋅kls⋅r⋅si
# ls⋅⎝- C₃ ⋅sin(C₁⋅r + C₂)⋅sin(C₃⋅z + C₄) + C₃ ⋅sin(C₃⋅z + C₄)⎠ + ──────────────
#
#
#
# n(C₁⋅r + C₂)⋅sin(C₃⋅z + C₄) + C₁⋅kls⋅sin(C₃⋅z + C₄)⋅cos(C₁⋅r + C₂)
# ──────────────────────────────────────────────────────────────────
#                          r
#
# C₁⋅RN⋅kls⋅cos(C₁⋅RN + C₂)⋅cos(C₃⋅z + C₄)   C₁⋅RS⋅kls⋅cos(C₁⋅RS + C₂)⋅cos(C₃⋅z
# ──────────────────────────────────────── - ───────────────────────────────────
#                    C₃                                         C₃
#
#
#              2                           2                           2
# + C₄)   C₃⋅RN ⋅kls⋅cos(C₃⋅z + C₄)   C₃⋅RS ⋅kls⋅cos(C₃⋅z + C₄)   Cb⋅RN ⋅Rhop⋅T_
# ───── + ───────────────────────── - ───────────────────────── + ──────────────
# ...
